# %%
def user_name():
    user_name = input("Enter your name: ")
    print(f"Hello, {user_name}!")
    for i in range(3):
        print(f"Welcome, {user_name}! This is message number {i + 1}.")

user_name()
# Out:
# Hello, Joseph Baker!
# Welcome, Joseph Baker! This is message number 1.
# Welcome, Joseph Baker! This is message number 2.
# Welcome, Joseph Baker! This is message number 3.

# %%
def practice():
    print("Let's practice Python functions!")
    for i in range(3):
        print(f"Practice round {i + 1}: Write a simple function.")

practice()
# Out:
# Let's practice Python functions!
# Practice round 1: Write a simple function.
# Practice round 2: Write a simple function.
# Practice round 3: Write a simple function.
