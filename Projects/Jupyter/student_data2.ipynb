# %% [markdown]
# # Student Data
# This Notebook analyizes pass/fail data for a class.

# %%
data = [14, 22, 24, 6, 42, 67, 53]
print(data)
# Out:
# [14, 22, 24, 6, 42, 67, 53]

# %%
# %pip install numpy
# Out:
# ...
#   Using cached numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 1.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/12.7 MB 1.0 MB/s eta 0:00:13
#    -- ------------------------------------- 0.8/12.7 MB 730.0 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.7 MB 730.0 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.7 MB 730.0 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.7 MB 730.0 kB/s eta 0:00:17
#    --- ------------------------------------ 1.0/12.7 MB 512.7 kB/s eta 0:00:23
# ...

# %%
import numpy as np

grades = np.array(data)

print(grades)
